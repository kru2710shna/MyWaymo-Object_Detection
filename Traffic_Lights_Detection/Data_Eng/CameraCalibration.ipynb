# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# Read Image in a Calibration Image
img3 = mpimg.imread('Data/GOPR0032.jpg')
plt.imshow(img)

# %%
# Arrays to store objects points and image points from all the images 

objpoints = [] # 3D points in real world space
imgpoints= [] # 2D points in image plane

objp= np.zeros((6*8,3), np.float32)
objp[:,:2] = np.mgrid[0:8,0:6].T.reshape(-1,2)

# Detect Corners of the Baord
gray = cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)

# Find all the chessboard corners
ret, corners = cv2.findChessboardCorners(gray,(8,6),None)

if ret:
    imgpoints.append(corners)
    objpoints.append(objp)

    img2 = img3.copy()
    img = cv2.drawChessboardCorners(img2, (8, 6), corners, ret)
    plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for plt
    plt.axis('off')
    plt.show()
    
plt.imshow(img3)
